# %% [markdown]
# notebook used to split the code into smaller pieces.

# %%
print ("noor")
3+4
# Out:
# noor
# 7

# %% [markdown]
# this cell is used to take input through input function

# %%
name = input("what is your name?")

# %% [markdown]
# this cell is used to print string

# %%
print("hellow" , name)
# Out:
# hellow noor
