# %% [markdown]
# 1.pandas #ye dataframes or kisi b kisam k data ko handle krny k liye use hoti ha jis trha excel pe data pe kam hota ha
# issi trha pandas main b data pe kam hota ha or jo functioning excel krta ha wohi pandas python main krta ha
# 2.numpy #data type ko samjhny k liye hoti ha
# 3.matplotlib #plots or graphes bnany k liye use hoti ha
# 4.seaborn # based on matploylib
# 5.plotly #interective plots bnany k liye use hoti ha inter-actives graphs k liye animated graphs k liye use hoti ha
# 6.scipy # scientific computing k liye use hoti ha
# 7.scikit-learn #machine learning k liye usehoti ha data ki pridictions k liye b use hoti ha
# 8.streamlit #dashboard k liye b use hoti ha

# %%
pip install pandas numpy matplotlib seaborn plotly

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import plotly as px
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# Cell In[15], line 3
#       1 import pandas as pd
#       2 import numpy as np
# ----> 3 import matplotlib.pyplot as plt
#       4 import seaborn as sns
#       5 import plotly as px
#
# File c:\Users\AD\AppData\Local\Programs\Python\Python313\Lib\site-packages\matplotlib\__init__.py:263
#     258         if parse_version(module.__version__) < parse_version(minver):
#     259             raise ImportError(f"Matplotlib requires {modname}>={minver}; "
#     260                               f"you have {module.__version__}")
# --> 263 _check_versions()
#     266 # The decorator ensures this always returns the same handler (and it is only
#     267 # attached once).
#     268 @functools.cache
#     269 def _ensure_handler():
#
# ...
