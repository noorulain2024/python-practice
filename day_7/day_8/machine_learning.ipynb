# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression

# %%
df = sns.load_dataset('titanic')

# %%
df
# Out:
#      survived  pclass     sex   age  sibsp  parch     fare embarked   class  \
# 0           0       3    male  22.0      1      0   7.2500        S   Third
# 1           1       1  female  38.0      1      0  71.2833        C   First
# 2           1       3  female  26.0      0      0   7.9250        S   Third
# 3           1       1  female  35.0      1      0  53.1000        S   First
# 4           0       3    male  35.0      0      0   8.0500        S   Third
# ..        ...     ...     ...   ...    ...    ...      ...      ...     ...
# 886         0       2    male  27.0      0      0  13.0000        S  Second
# 887         1       1  female  19.0      0      0  30.0000        S   First
# 888         0       3  female   NaN      1      2  23.4500        S   Third
# 889         1       1    male  26.0      0      0  30.0000        C   First
# 890         0       3    male  32.0      0      0   7.7500        Q   Third
#
#        who  adult_male deck  embark_town alive  alone
# ...

# %%
# how to select two columns
df_linear = df[["age", "fare"]]
df_linear
# Out:
#       age     fare
# 0    22.0   7.2500
# 1    38.0  71.2833
# 2    26.0   7.9250
# 3    35.0  53.1000
# 4    35.0   8.0500
# ..    ...      ...
# 886  27.0  13.0000
# 887  19.0  30.0000
# 888   NaN  23.4500
# 889  26.0  30.0000
# 890  32.0   7.7500
#
# [891 rows x 2 columns]

# %%
X = df_linear[['age']]
y = df_linear['fare']

# %%
df_linear.isnull().sum()
# Out:
# age     177
# fare      0
# dtype: int64

# %%
df_linear['age'].isnull().sum()
# Out:
# np.int64(177)

# %%
sns.lmplot(data= df_linear, x='age', y='fare')

# %%
sns.boxplot(data = df_linear, y='age')
# Out:
# <Axes: ylabel='age'>

# %%
df_linear = df_linear[(df_linear['age']>4) & (df_linear['age']<62)]

# %%
sns.boxplot(data= df_linear, y='fare')
# Out:
# <Axes: ylabel='fare'>

# %%
# IQR method
#Q1= df_linear['fare'].quantile(0.25)
#Q3= df_linear['fare'].quantile(0.75)
#IQR = Q3 - Q1
#upper_bound = Q3 + 1.5* IQR
#lower_bound = Q1- 1.5 * IQR
df_linear = df_linear[(df_linear['fare']> 3) & (df_linear['fare']<47)]

# %%
sns.lmplot(x= 'age', y= 'fare',data= df_linear)

# %%
X = df_linear[['age']]
y= df_linear['fare']

# %%
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression
# model ko bula lyn
model = LinearRegression()
# train the model
model.fit(X,y)
# prediction
model.predict(X_test)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[2], line 6
#       4 model = LinearRegression()
#       5 # train the model
# ----> 6 model.fit(X,y)
#       7 # prediction
#       8 model.predict(X_test)
#
# NameError: name 'X' is not defined

# %%
# model eveluation with matrics
# r2
# mean squared method
# MAE 
# RMSE
X_train, X_test, y_train, y_test = train_test_split(X,y, train_size = 0.8)
# model
model = LinearRegression()
# train 
model.fit(X_train,y_train)
# prediction
model.predict(X_test)
prediction =  model.predict(X_test)

# %%
sns.scatterplot(y = prediction, x= y_test)
# Out:
# <Axes: xlabel='fare'>

# %%
model.score(X_test , y_test)
# Out:
# -0.04345600782938308

# %%
import numpy as np
from sklearn.metrics import mean_squared_error, mean_absolute_error, r2_score
MAE = mean_absolute_error(y_true=y_test, y_pred=prediction)
MSE = mean_squared_error(y_true=y_test, y_pred=prediction)
#RMSE = mean_squared_error(y_true=y_test, y_pred=prediction, squared=False)
R2 = r2_score(y_true=y_test, y_pred= prediction)

# %%
print("MAE:",MAE)
print("MSE:",MSE)
print("RMSE:",RMSE)
print("R_squared:",R2)
# Out:
# MAE: 7.9692476551074725
# MSE: 86.96584570989283
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[22], line 3
#       1 print("MAE:",MAE)
#       2 print("MSE:",MSE)
# ----> 3 print("RMSE:",RMSE)
#       4 print("R_squared:",R2)
#
# NameError: name 'RMSE' is not defined

# %%
import numpy as np
RMSE = np.sqrt(MSE)
RMSE
# Out:
# np.float64(9.097610254871645)
