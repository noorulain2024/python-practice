# %% [markdown]
# # how to import dataset in pythoon using pandas library file
# written by dr. ammar toufail
#
# date: 7.12.2024
#
# email: ....

# %%
pip install pandas

# %%
import pandas as pd

# %%
df = pd.read_excel("pandas_01_day6.xlsx")

# %%
df
# Out:
#     Height  Weight Favourite Dish
# 0      5.8     101  Chicken Pulao
# 1      6.2      92        Biryani
# 2      5.9      62  Karahi Ghosht
# 3      5.9      95  Chicken Pulao
# 4      5.9      55  Chicken Pulao
# ..     ...     ...            ...
# 82     5.4      55          Pasta
# 83     5.9      73  Karahi Ghosht
# 84     5.4      61        Biryani
# 85     6.2      68  Chicken Pulao
# 86     5.1      96        Biryani
#
# [87 rows x 3 columns]

# %%
df.head()
# Out:
#    Height  Weight Favourite Dish
# 0     5.8     101  Chicken Pulao
# 1     6.2      92        Biryani
# 2     5.9      62  Karahi Ghosht
# 3     5.9      95  Chicken Pulao
# 4     5.9      55  Chicken Pulao

# %%
df.index
# Out:
# RangeIndex(start=0, stop=87, step=1)

# %%
df.columns
# Out:
# Index(['Height', 'Weight', 'Favourite Dish'], dtype='object')

# %%
df.describe()
# Out:
#           Height      Weight
# count  87.000000   87.000000
# mean    5.499425   70.436782
# std     0.787626   16.748968
# min     0.700000   25.000000
# 25%     5.200000   60.000000
# 50%     5.600000   70.000000
# 75%     5.850000   80.000000
# max     8.000000  125.000000

# %%
df.T
# Out:
#                            0        1              2              3   \
# Height                    5.8      6.2            5.9            5.9
# Weight                    101       92             62             95
# Favourite Dish  Chicken Pulao  Biryani  Karahi Ghosht  Chicken Pulao
#
#                            4        5      6        7        8        9   ...  \
# Height                    5.9      5.3    5.6      5.9      5.1      5.4  ...
# Weight                     55       59     50       76       78       68  ...
# Favourite Dish  Chicken Pulao  Biryani  Pasta  Biryani  Biryani  Biryani  ...
#
#                      77             78       79     80             81     82  \
# Height              5.5            5.3      5.3    5.4            5.5    5.4
# Weight               85             72       62     55             52     55
# Favourite Dish  Biryani  Karahi Ghosht  Biryani  Pasta  Karahi Ghosht  Pasta
#
#                            83       84             85       86
# Height                    5.9      5.4            6.2      5.1
# Weight                     73       61             68       96
# Favourite Dish  Karahi Ghosht  Biryani  Chicken Pulao  Biryani
#
# [3 rows x 87 columns]
